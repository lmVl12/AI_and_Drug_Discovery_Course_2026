# %% [markdown]
# <a href="https://colab.research.google.com/github/lmVl12/AI_and_Drug_Discovery_Course_2026/blob/main/Assignment_2_QSAR_data_curation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AI And Biotechnology/Bioinformatics**
#
# ## **AI and Drug Discovery Course: QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# ### **1.1 Environment Setup**
# The Google Colab environment is integrated with Google Drive to facilitate persistent data storage and project organization. The chembl_webresource_client is installed to provide programmatic access to the ChEMBL database API.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %% [markdown]
# #### **Library Imports**
# The **chembl_webresource_client** is installed to provide programmatic access to the ChEMBL database API.
# Essential Python libraries are imported for data manipulation and database interaction:
# * pandas for data handling
# * new_client to perform targeted queries against the ChEMBL database.

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.9 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.1 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 4.2 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### **1.2 Target Identification (FLT3)**
# The study focuses on the Receptor-type tyrosine-protein kinase FLT3 (Homo sapiens). To ensure biological accuracy, the target is queried using its UniProt ID (P36888). ChEMBL ID CHEMBL1974 is identified as the primary target for bioactivity data retrieval.

# %%
target = new_client.target
target_query = target.search("P36888")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
#
#                                            pref_name  score  \
# 0         Receptor-type tyrosine-protein kinase FLT3   17.0
# 1  Aurora kinase B/Receptor-type tyrosine-protein...   15.0
# 2  Protein cereblon/Tyrosine-protein kinase recep...   15.0
# 3    von Hippel-Lindau disease tumor suppressor/FLT3   13.0
#
#    species_group_flag target_chembl_id  \
# 0               False       CHEMBL1974
# 1               False    CHEMBL3430908
# 2               False    CHEMBL4630730
# 3               False    CHEMBL4523735
#
#                                    target_components  \
# 0  [{'accession': 'P36888', 'component_descriptio...
# 1  [{'accession': 'P36888', 'component_descriptio...
# 2  [{'accession': 'P36888', 'component_descriptio...
# 3  [{'accession': 'P36888', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1            SELECTIVITY GROUP    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3  PROTEIN-PROTEIN INTERACTION    9606

# %% [markdown]
# ### **1.3 Bioactivity Data Retrieval**
# Experimental records for CHEMBL1974 are retrieved, specifically filtering for IC50 measurements. The raw dataset is exported as bioactivity_raw_data.csv and backed up to the Google Drive /data directory to ensure data integrity.

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1974'

# %%
# Retrieving IC50 bioactivity data for selected target
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
# Initial data assembly for curation
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       866063                  []
# 1        None             None       872532                  []
# 2        None             None       872564                  []
# 3        None             None       879718                  []
# 4        None             None       884645                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 1    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 2    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 3    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 4    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                            target_pref_name target_tax_id  \
# 0    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 1    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 2    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 3    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 4    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
#
#   text_value  toid  type units    uo_units upper_value  value
# 0       None  None  IC50    uM  UO_0000065        None  0.128
# 1       None  None  IC50    uM  UO_0000065        None   0.22
# 2       None  None  IC50    uM  UO_0000065        None   8.79
# 3       None  None  IC50    uM  UO_0000065        None   1.91
# 4       None  None  IC50    uM  UO_0000065        None   30.0
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
# Exporting raw database results for traceability
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %%
# Archiving raw data to Google Drive project folder
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
# Verifying successful archival of the 5.7MB dataset
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 5659
# -rw------- 1 root root 5793932 Jan 21 15:26 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,866063,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc2cc1OCCCN1CCC(C)CC1,,,CHEMBL1135998,J Med Chem,2002,"{'bei': '11.95', 'le': '0.22', 'lle': '1.61', 'sei': '7.47'}",CHEMBL330863,,CHEMBL330863,6.89,0,http://www.openphacts.org/units/Nanomolar,237034,=,1,1,=,,IC50,nM,,128.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,0.128
# ,,872532,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc2cc1OCCCN1CCCCC1,,,CHEMBL1135998,J Med Chem,2002,"{'bei': '11.83', 'le': '0.22', 'lle': '1.63', 'sei': '7.21'}",CHEMBL124660,TANDUTINIB,CHEMBL124660,6.66,0,http://www.openphacts.org/units/Nanomolar,237044,=,1,1,=,,IC50,nM,,220.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,0.22
# ,,872564,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc1OCCCN1CCCCC1C,,,CHEMBL1135998,J Med Chem,2002,"{'bei': '9.30', 'le': '0.17', 'lle': '0.55', 'sei': '4.73'}",CHEMBL126699,,CHEMBL126699,5.06,0,http://www.openphacts.org/units/Nanomolar,237033,=,1,1,=,,IC50,nM,,8790.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,8.79
# ,,879718,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc1OCCCN1CCC(C)CC1,,,CHEMBL1135998,J Med Chem,2002,"{'bei': '10.52', 'le': '0.20', 'lle': '1.36', 'sei': '5.35'}",CHEMBL445636,,CHEMBL445636,5.72,0,http://www.openphacts.org/units/Nanomolar,237035,=,1,1,=,,IC50,nM,,1910.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,1.91
# ,,884645,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc(-c2cccnc2)n1,,,CHEMBL1135998,J Med Chem,2002,,CHEMBL941,IMATINIB,CHEMBL941,,0,http://www.openphacts.org/units/Nanomolar,237053,>,1,1,>,,IC50,nM,,30000.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,30.0
# ,,886058,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,COCCOc1cc2ncnc(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)c2cc1OC,,,CHEMBL1135998,J Med Chem,2002,"{'bei': '12.81', 'le': '0.24', 'lle': '2.55', 'sei': '6.46'}",CHEMBL124035,,CHEMBL124035,6.35,0,http://www.openphacts.org/units/Nanomolar,237061,=,1,1,=,,IC50,nM,,450.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,0.45
# ,,895434,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc2cc1OCCCN1CCOCC1,,,CHEMBL1135998,J Med Chem,2002,"{'bei': '13.10', 'le': '0.25', 'lle': '3.52', 'sei': '7.29'}",CHEMBL125898,,CHEMBL125898,7.40,0,http://www.openphacts.org/units/Nanomolar,237043,=,1,1,=,,IC50,nM,,40.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,0.04
# ,,895457,[],CHEMBL679499,Inhibition of Flt3/ITD mutant expressed in hematopoietic cells or AML cell lines; range = 30-100 nM,F,,,BAO_0000190,BAO_0000219,cell-based format,COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc2cc1OCCCN1CCOCC1,,,CHEMBL1135998,J Med Chem,2002,,CHEMBL125898,,CHEMBL125898,7.00,0,http://www.openphacts.org/units/Nanomolar,237043,=,1,1,=,,IC50,nM,,100.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,nM,UO_0000065,,100.0
# ,,896682,[],CHEMBL766072,Inhibition of chimeric PDGF receptor with FLT-3 cytoplasmic domain phosphorylation in CHO cells,B,,,BAO_0000190,BAO_0000219,cell-based format,COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc2cc1OCCCN1CCCCC1C,,,CHEMBL1135998,J Med Chem,2002,"{'bei': '11.62', 'le': '0.22', 'lle': '1.28', 'sei': '7.26'}",CHEMBL107599,,CHEMBL107599,6.70,0,http://www.openphacts.org/units/Nanomolar,237032,=,1,1,=,,IC50,nM,,200.0,CHEMBL1974,Homo sapiens,Receptor-type tyrosine-protein kinase FLT3,9606,,,IC50,uM,UO_0000065,,0.2

# %% [markdown]
# ### **1.4 Data Preprocessing & Categorization**
# ####**Cleaning and Bioactivity Classification**
# The dataset undergoes systematic curation to ensure data quality:**
# * Handling Missing Values: Rows lacking a standard_value are removed to ensure only valid experimental results are analyzed.
# * Classification: Based on IC50 potency, compounds are categorized into:
#   * Active: $\text{IC50} \le 1000 \text{ nM}$
#   * Inactive: $\text{IC50} \ge 10000 \text{ nM}$
#   * Intermediate: Values between 1000 and 10000 nM.
# * Feature Selection: Relevant columns (Molecule ChEMBL ID, Canonical SMILES, and Bioactivity Class) are extracted.

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %%
# Filtering the dataset to remove records lacking bioactivity values (IC50)
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       866063                  []
# 1        None             None       872532                  []
# 2        None             None       872564                  []
# 3        None             None       879718                  []
# 4        None             None       884645                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 1    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 2    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 3    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
# 4    CHEMBL766072  Inhibition of chimeric PDGF receptor with FLT-...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                            target_pref_name target_tax_id  \
# 0    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 1    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 2    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 3    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
# 4    Homo sapiens  Receptor-type tyrosine-protein kinase FLT3          9606
#
#   text_value  toid  type units    uo_units upper_value  value
# 0       None  None  IC50    uM  UO_0000065        None  0.128
# 1       None  None  IC50    uM  UO_0000065        None   0.22
# 2       None  None  IC50    uM  UO_0000065        None   8.79
# 3       None  None  IC50    uM  UO_0000065        None   1.91
# 4       None  None  IC50    uM  UO_0000065        None   30.0
#
# [5 rows x 46 columns]

# %%
# Categorizing compounds into potency classes based on IC50 values (nM)
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %%
# Consolidating molecular identifiers, structures, and potency labels
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %%
# Constructing the curated dataframe for subsequent analysis
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL330863  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 1       CHEMBL124660  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 2       CHEMBL126699  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 3       CHEMBL445636  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 4          CHEMBL941  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
#
#   standard_value bioactivity_class
# 0          128.0            active
# 1          220.0            active
# 2         8790.0      intermediate
# 3         1910.0      intermediate
# 4        30000.0          inactive

# %% [markdown]
# ### **1.5. Chemical Structure Validation**
# A final structural check is performed to remove compounds without valid chemical structures. Any rows with NaN, empty, or "None" SMILES values are dropped. This ensures the dataset is compatible with molecular descriptor calculations in Part 2.

# %%
# Structural validation: dropping entries with missing or empty SMILES strings
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL330863  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 1       CHEMBL124660  COc1cc2c(N3CCN(C(=O)Nc4ccc(OC(C)C)cc4)CC3)ncnc...
# 2       CHEMBL126699  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 3       CHEMBL445636  COc1cc2c(N3CCN(C(=O)Nc4ccc(C#N)cc4)CC3)ncnc2cc...
# 4          CHEMBL941  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
#
#   standard_value bioactivity_class
# 0          128.0            active
# 1          220.0            active
# 2         8790.0      intermediate
# 3         1910.0      intermediate
# 4        30000.0          inactive

# %%
# Monitoring curation efficiency (Initial vs. Final records)
len(df1)
# Out:
# 7096

# %%
len(df3)
# Out:
# 6960

# %% [markdown]
# ### **1.6. Export of Curated Dataset**
# The preprocessed dataset is saved as bioactivity_preprocessed_data.csv. This file is synchronized with Google Drive to serve as the input for subsequent QSAR modeling.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**
